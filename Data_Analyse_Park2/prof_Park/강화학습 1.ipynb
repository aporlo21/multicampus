# %%
pip install Gym
# Out:
# Requirement already satisfied: Gym in /usr/local/lib/python3.6/dist-packages (0.10.11)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from Gym) (2.21.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from Gym) (1.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from Gym) (1.12.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from Gym) (1.16.5)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from Gym) (1.4.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->Gym) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->Gym) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->Gym) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->Gym) (3.0.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->Gym) (0.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
from gym.envs.registration import register

# %%
register(id = "FrozenLakeNotSlippery-v1",
        entry_point = "gym.envs.toy_text:FrozenLakeEnv",
        kwargs = {"map_name" : "4x4", "is_slippery" : False})
#id가 게임 환경의 이름이다. 동일 이름으로는 등록하면 안됨
# "SFFF"
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-11-7e1e62c0810d> in <module>()
#       1 register(id = "FrozenLakeNotSlippery-v1",
#       2         entry_point = "gym.envs.toy_text:FrozenLakeEnv",
# ----> 3         kwargs = {"map_name" : "4x4", "is_slippery" : False})
#       4 #id가 게임 환경의 이름이다. 동일 이름으로는 등록하면 안됨
#       5 # "SFFF"
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py in register(id, **kwargs)
#     166
#     167 def register(id, **kwargs):
# --> 168     return registry.register(id, **kwargs)
#     169
#     170 def make(id, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py in register(self, id, **kwargs)
#     159     def register(self, id, **kwargs):
#     160         if id in self.env_specs:
# --> 161             raise error.Error('Cannot re-register id: {}'.format(id))
#     162         self.env_specs[id] = EnvSpec(id, **kwargs)
#     163
#
# Error: Cannot re-register id: FrozenLakeNotSlippery-v1

# %%
env = gym.make("FrozenLakeNotSlippery-v1") # 환경 생성
env.reset()
# Out:
# 0

# %%
complete_actions=[2,2,1,1,1,2]
for action in complete_actions:
  new_state, reward, done, _ = env.step(action)#action을 적용
  env.render() #현재 state 정보가 출력된다.
  if done is True :
    print('도착, reward: {}'.format(reward))
# Out:
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 도착, reward: 1.0

# %%
##미끄러운 경우 어떻게 되나 해보자!
register(id = "FrozenLakeNotSlippery-v3",
        entry_point = "gym.envs.toy_text:FrozenLakeEnv",
        kwargs = {"map_name" : "4x4", "is_slippery" : True})

# %%
env = gym.make("FrozenLakeNotSlippery-v3") # 환경 생성
env.reset()
complete_actions=[2,2,1,1,1,2]
for action in complete_actions:
  new_state, reward, done, _ = env.step(action)#action을 적용
  env.render() #현재 state 정보가 출력된다.
  if done is True :
    print('도착, reward: {}'.format(reward))
# Out:
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 도착, reward: 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# 도착, reward: 0

# %%
register(id = "FrozenLakeNotSlippery-v4",
        entry_point = "gym.envs.toy_text:FrozenLakeEnv",
        kwargs = {"map_name" : "4x4", "is_slippery" : False})

# %%
env = gym.make("FrozenLakeNotSlippery-v4")
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %%
import random
env.action_space.n # action의 종류, 수
#random.randint(0, env.action_space.n - 1 ) #0~3사이의 랜덤값이 도출되도록 한다.
# Out:
# 1

# %%
num_episodes=2000
rList=[]

for i in range(num_episodes):
  env.reset()
  done = False
  rAll = 0
  while not done:
      action=random.randint(0,env.action_space.n-1) #0-3 정수
      _state, reward, done, _info = env.step(action)
      rAll += reward
  rList.append(rAll)
print("Success rate:" + str(sum(rList)/num_episodes))
plt.plot(rList)
plt.show()
# Out:
# Success rate:0.0145
# <function matplotlib.pyplot.show>
