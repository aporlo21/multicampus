# %%
# Let`s import all packages that we may need:

import sys 
import numpy as np # linear algebra
from scipy.stats import randint
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv), data manipulation as in SQL
import matplotlib.pyplot as plt # this is used for the plot the graph 
import seaborn as sns # used for plot interactive graph. 
from sklearn.model_selection import train_test_split # to split the data into two parts
# from sklearn.cross_validation import KFold # use for cross validation
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler # for normalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline # pipeline making
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel
from sklearn import metrics # for the check the error and accuracy of the model
from sklearn.metrics import mean_squared_error,r2_score


## for Deep-learing:
import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import itertools
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Importing the data and data processing
# ### 데이터 불러오기 및 전처리 과정

# %%
# raw파일로 불러와서 형식확인

# path = 'max_power.csv'
# with open(path, 'rb') as f:
#     buf  = f.read()
#     print(buf)

# %%
df = pd.read_csv('max_power.csv', encoding = 'euc-kr') # 한글 인코딩
df.head()
# Out:
#       년  월   일  설비용량(MW)  공급능력(MW)  최대전력(MW)  공급예비력(MW)  공급예비율(%)  \
# 0  2019  9  16    122490     88841     71926      16915      23.5
# 1  2019  9  15    122490     87737     58401      29336      50.2
# 2  2019  9  14    122490     87824     55077      32747      59.5
# 3  2019  9  13    122490     87867     50583      37284      73.7
# 4  2019  9  12    122490     89300     55025      34275      62.3
#
#             최대전력기준일시
# 0  2019/09/16(17:00)
# 1  2019/09/15(20:00)
# 2  2019/09/14(20:00)
# 3  2019/09/13(20:00)
# 4  2019/09/12(01:00)

# %%
df.head()
# Out:
#       년  월   일  설비용량(MW)  공급능력(MW)  최대전력(MW)  공급예비력(MW)  공급예비율(%)  \
# 0  2019  9  16    122490     88841     71926      16915      23.5
# 1  2019  9  15    122490     87737     58401      29336      50.2
# 2  2019  9  14    122490     87824     55077      32747      59.5
# 3  2019  9  13    122490     87867     50583      37284      73.7
# 4  2019  9  12    122490     89300     55025      34275      62.3
#
#             최대전력기준일시
# 0  2019/09/16(17:00)
# 1  2019/09/15(20:00)
# 2  2019/09/14(20:00)
# 3  2019/09/13(20:00)
# 4  2019/09/12(01:00)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 9 columns):
# 년            259 non-null int64
# 월            259 non-null int64
# 일            259 non-null int64
# 설비용량(MW)     259 non-null int64
# 공급능력(MW)     259 non-null int64
# 최대전력(MW)     259 non-null int64
# 공급예비력(MW)    259 non-null int64
# 공급예비율(%)     259 non-null float64
# 최대전력기준일시     259 non-null object
# dtypes: float64(1), int64(7), object(1)
# memory usage: 18.3+ KB

# %%
df.dtypes
# Out:
# 년              int64
# 월              int64
# 일              int64
# 설비용량(MW)       int64
# 공급능력(MW)       int64
# 최대전력(MW)       int64
# 공급예비력(MW)      int64
# 공급예비율(%)     float64
# 최대전력기준일시      object
# dtype: object

# %%
df.shape # 열 : columns 수
# Out:
# (259, 9)

# %%
# df.describe() # 요약된 통계 결과 도출

# %%
# string = df.columns

# %%
# df.drop(index=string, inplace=True)

# %%
# for j in range(1,7):
#        print(df.iloc[:, j].unique())

# %% [markdown]
# #  Dealing with missing values  'nan' with a test statistic
# ### 결측치를 test 통계치로 대체

# %%
# ## finding all columns that have nan:
# # nan 값 지닌 모든 칼럼 탐색

# droping_list_all=[]
# for j in range(0,7):
#     if not df.iloc[:, j].notnull().all():
#         droping_list_all.append(j)        
#         #print(df.iloc[:,j].unique())
# droping_list_all

# %%
# # filling nan with mean in any columns
# # 해당 칼럼 내에 결측치를 mean값으로 채워주기

# for j in range(0,7):        
#         df.iloc[:,j]=df.iloc[:,j].fillna(df.iloc[:,j].mean())

# %%
# # another sanity check to make sure that there are not more any nan
# # 더이상 nan값 없음을 체크 하기 위한 구문 

# df.isnull().sum()

# %%
# df.describe()

# %% [markdown]
# ## 최대 전력기준일시 (object) 변환
# ### 공급예비율 (float) 변환

# %%
f = lambda x: (x*2, x*3)
f(2)
# Out:
# (4, 6)

# %%
df['최대전력기준일시2'] = df['최대전력기준일시'].transform(lambda x: x[:-7])
# df['최대전력기준일시3'] = df['최대전력기준일시'].transform(lambda x: x[-7:])

# %%
display(df.최대전력기준일시2.head())
# df.최대전력기준일시3.head()
# Out:
# 0    2019/09/16
# 1    2019/09/15
# 2    2019/09/14
# 3    2019/09/13
# 4    2019/09/12
# Name: 최대전력기준일시2, dtype: object

# %%
df['최대전력기준일시2'] = pd.to_datetime(df['최대전력기준일시2'])
df['최대전력기준일시2']
# Out:
# 0     2019-09-16
# 1     2019-09-15
# 2     2019-09-14
# 3     2019-09-13
# 4     2019-09-12
# 5     2019-09-11
# 6     2019-09-10
# 7     2019-09-09
# 8     2019-09-08
# 9     2019-09-07
# 10    2019-09-06
# 11    2019-09-05
# 12    2019-09-04
# 13    2019-09-03
# 14    2019-09-02
# 15    2019-09-01
# 16    2019-08-31
# 17    2019-08-30
# 18    2019-08-29
# 19    2019-08-28
# 20    2019-08-27
# 21    2019-08-26
# 22    2019-08-25
# 23    2019-08-24
# 24    2019-08-23
# 25    2019-08-22
# 26    2019-08-21
# 27    2019-08-20
# 28    2019-08-19
# 29    2019-08-18
#          ...
# 229   2019-01-30
# 230   2019-01-29
# 231   2019-01-28
# 232   2019-01-27
# 233   2019-01-26
# 234   2019-01-25
# 235   2019-01-24
# 236   2019-01-23
# 237   2019-01-22
# 238   2019-01-21
# 239   2019-01-20
# 240   2019-01-19
# 241   2019-01-18
# 242   2019-01-17
# 243   2019-01-16
# 244   2019-01-15
# 245   2019-01-14
# 246   2019-01-13
# 247   2019-01-12
# 248   2019-01-11
# 249   2019-01-10
# 250   2019-01-09
# 251   2019-01-08
# 252   2019-01-07
# 253   2019-01-06
# 254   2019-01-05
# 255   2019-01-04
# 256   2019-01-03
# 257   2019-01-02
# 258   2019-01-01
# Name: 최대전력기준일시2, Length: 259, dtype: datetime64[ns]

# %%
# df.drop(['최대전력기준일시3'], axis=1)

# del df['최대전력기준일시3']
# df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 10 columns):
# 년            259 non-null int64
# 월            259 non-null int64
# 일            259 non-null int64
# 설비용량(MW)     259 non-null int64
# 공급능력(MW)     259 non-null int64
# 최대전력(MW)     259 non-null int64
# 공급예비력(MW)    259 non-null int64
# 공급예비율(%)     259 non-null float64
# 최대전력기준일시     259 non-null object
# 최대전력기준일시2    259 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(7), object(1)
# memory usage: 20.3+ KB

# %%
df = df.drop(['년','월','일'], axis=1)
df.set_index('최대전력기준일시2', inplace=False)
# Out:
#             설비용량(MW)  공급능력(MW)  최대전력(MW)  공급예비력(MW)  공급예비율(%)  \
# 최대전력기준일시2
# 2019-09-16    122490     88841     71926      16915      23.5
# 2019-09-15    122490     87737     58401      29336      50.2
# 2019-09-14    122490     87824     55077      32747      59.5
# 2019-09-13    122490     87867     50583      37284      73.7
# 2019-09-12    122490     89300     55025      34275      62.3
# 2019-09-11    122490     92360     73271      19089      26.1
# 2019-09-10    122490     91977     78650      13327      16.9
# 2019-09-09    122973     92717     78980      13737      17.4
# 2019-09-08    122973     92823     65686      27137      41.3
# 2019-09-07    122973     94243     68972      25271      36.6
# 2019-09-06    122973     96032     79916      16116      20.2
# 2019-09-05    122973     96786     79390      17396      21.9
# 2019-09-04    122973     95358     77939      17419      22.3
# 2019-09-03    122973     95152     77067      18085      23.5
# 2019-09-02    122973     96412     76231      20181      26.5
# 2019-09-01    122973     97308     61847      35461      57.3
# 2019-08-31    122973     97968     63393      34575      54.5
# 2019-08-30    122973     99882     73735      26147      35.5
# 2019-08-29    121147     99833     76683      23150      30.2
# 2019-08-28    121147     99232     79037      20195      25.6
# 2019-08-27    121147     99787     77998      21789      27.9
# 2019-08-26    121147     99869     79478      20391      25.7
# 2019-08-25    121147     98253     63326      34927      55.2
# 2019-08-24    121147     98115     64735      33380      51.6
# 2019-08-23    121147    100326     79012      21314      27.0
# 2019-08-22    121147    100471     82264      18207      22.1
# 2019-08-21    121147     99640     83782      15858      18.9
# 2019-08-20    121147     98607     83162      15445      18.6
# 2019-08-19    121147     98558     81590      16968      20.8
# 2019-08-18    121147     96791     66051      30740      46.5
# ...              ...       ...       ...        ...       ...
# 2019-01-30    119350     99728     80741      18987      23.5
# 2019-01-29    119350    100298     81215      19083      23.5
# 2019-01-28    119350     99745     80399      19346      24.1
# 2019-01-27    119350     97470     65189      32281      49.5
# 2019-01-26    119350     97796     68954      28842      41.8
# 2019-01-25    119350     99688     81007      18681      23.1
# 2019-01-24    119350     99535     80239      19296      24.0
# 2019-01-23    119092    100337     80794      19543      24.2
# 2019-01-22    119092    100320     81134      19186      23.6
# 2019-01-21    119092     99530     82668      16862      20.4
# 2019-01-20    119092     99561     65830      33731      51.2
# 2019-01-19    119092     99028     67950      31078      45.7
# 2019-01-18    119092    101500     81668      19832      24.3
# 2019-01-17    119092    101011     82611      18400      22.3
# 2019-01-16    119092    101806     84401      17405      20.6
# 2019-01-15    119092     98347     81378      16969      20.9
# 2019-01-14    119092     98333     81783      16550      20.2
# 2019-01-13    119092     97990     64545      33445      51.8
# 2019-01-12    119092     98303     68147      30156      44.3
# 2019-01-11    119092     99990     81941      18049      22.0
# 2019-01-10    119092    101064     83833      17231      20.6
# 2019-01-09    119092    100827     85392      15435      18.1
# 2019-01-08    119092    100948     83818      17130      20.4
# 2019-01-07    119092    101091     84074      17017      20.2
# 2019-01-06    119092     98748     66493      32255      48.5
# 2019-01-05    119092     99505     69496      30009      43.2
# 2019-01-04    119092    100294     84746      15548      18.3
# 2019-01-03    119092     99695     84196      15499      18.4
# 2019-01-02    119092    101149     82437      18712      22.7
# 2019-01-01    119092    100043     65493      34550      52.8
#
#                      최대전력기준일시
# 최대전력기준일시2
# 2019-09-16  2019/09/16(17:00)
# 2019-09-15  2019/09/15(20:00)
# 2019-09-14  2019/09/14(20:00)
# 2019-09-13  2019/09/13(20:00)
# 2019-09-12  2019/09/12(01:00)
# 2019-09-11  2019/09/11(11:00)
# 2019-09-10  2019/09/10(17:00)
# 2019-09-09  2019/09/09(17:00)
# 2019-09-08  2019/09/08(20:00)
# 2019-09-07  2019/09/07(12:00)
# 2019-09-06  2019/09/06(17:00)
# 2019-09-05  2019/09/05(15:00)
# 2019-09-04  2019/09/04(17:00)
# 2019-09-03  2019/09/03(15:00)
# 2019-09-02  2019/09/02(17:00)
# 2019-09-01  2019/09/01(20:00)
# 2019-08-31  2019/08/31(20:00)
# 2019-08-30  2019/08/30(17:00)
# 2019-08-29  2019/08/29(11:00)
# 2019-08-28  2019/08/28(17:00)
# 2019-08-27  2019/08/27(17:00)
# 2019-08-26  2019/08/26(17:00)
# 2019-08-25  2019/08/25(20:00)
# 2019-08-24  2019/08/24(15:00)
# 2019-08-23  2019/08/23(17:00)
# 2019-08-22  2019/08/22(17:00)
# 2019-08-21  2019/08/21(17:00)
# 2019-08-20  2019/08/20(17:00)
# 2019-08-19  2019/08/19(17:00)
# 2019-08-18  2019/08/18(20:00)
# ...                       ...
# 2019-01-30  2019/01/30(10:00)
# 2019-01-29  2019/01/29(10:00)
# 2019-01-28  2019/01/28(10:00)
# 2019-01-27  2019/01/27(01:00)
# 2019-01-26  2019/01/26(09:00)
# 2019-01-25  2019/01/25(10:00)
# 2019-01-24  2019/01/24(10:00)
# 2019-01-23  2019/01/23(10:00)
# 2019-01-22  2019/01/22(10:00)
# 2019-01-21  2019/01/21(10:00)
# 2019-01-20  2019/01/20(24:00)
# 2019-01-19  2019/01/19(01:00)
# 2019-01-18  2019/01/18(10:00)
# 2019-01-17  2019/01/17(10:00)
# 2019-01-16  2019/01/16(10:00)
# 2019-01-15  2019/01/15(10:00)
# 2019-01-14  2019/01/14(10:00)
# 2019-01-13  2019/01/13(24:00)
# 2019-01-12  2019/01/12(11:00)
# 2019-01-11  2019/01/11(10:00)
# 2019-01-10  2019/01/10(10:00)
# 2019-01-09  2019/01/09(10:00)
# 2019-01-08  2019/01/08(10:00)
# 2019-01-07  2019/01/07(10:00)
# 2019-01-06  2019/01/06(20:00)
# 2019-01-05  2019/01/05(11:00)
# 2019-01-04  2019/01/04(10:00)
# 2019-01-03  2019/01/03(10:00)
# 2019-01-02  2019/01/02(10:00)
# 2019-01-01  2019/01/01(24:00)
#
# [259 rows x 6 columns]

# %%
df = df.set_index('최대전력기준일시2', inplace=False)

# %%
print(df['공급예비율(%)'].head())
# Out:
# 최대전력기준일시2
# 2019-09-16    23.5
# 2019-09-15    50.2
# 2019-09-14    59.5
# 2019-09-13    73.7
# 2019-09-12    62.3
# Name: 공급예비율(%), dtype: float64

# %%
print(df['최대전력(MW)'].head())
# Out:
# 최대전력기준일시2
# 2019-09-16    71926
# 2019-09-15    58401
# 2019-09-14    55077
# 2019-09-13    50583
# 2019-09-12    55025
# Name: 최대전력(MW), dtype: int64

# %%
print(df['공급예비율(%)'].index) # index type check
# Out:
# DatetimeIndex(['2019-09-16', '2019-09-15', '2019-09-14', '2019-09-13',
#                '2019-09-12', '2019-09-11', '2019-09-10', '2019-09-09',
#                '2019-09-08', '2019-09-07',
#                ...
#                '2019-01-10', '2019-01-09', '2019-01-08', '2019-01-07',
#                '2019-01-06', '2019-01-05', '2019-01-04', '2019-01-03',
#                '2019-01-02', '2019-01-01'],
#               dtype='datetime64[ns]', name='최대전력기준일시2', length=259, freq=None)

# %%
# print(data['최대전력기준일시'])
type(df['최대전력기준일시'])
# Out:
# pandas.core.series.Series

# %%
df.info()
# data. ____ : object자료형만 호출가능
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 259 entries, 2019-09-16 to 2019-01-01
# Data columns (total 6 columns):
# 설비용량(MW)     259 non-null int64
# 공급능력(MW)     259 non-null int64
# 최대전력(MW)     259 non-null int64
# 공급예비력(MW)    259 non-null int64
# 공급예비율(%)     259 non-null float64
# 최대전력기준일시     259 non-null object
# dtypes: float64(1), int64(4), object(1)
# memory usage: 14.2+ KB

# %% [markdown]
# # Data visualization
# ### data 시각화를 통해 전체적인 dataset 정보를 탐색한다
# ### EDA

# %%
from jupyterthemes import jtplot
jtplot.style(theme='gruvboxd', context='paper', spines=True, 
             ticks=True, grid=True, gridlines='dotted', figsize=(10,7.8))

# %%
# 한글 깨짐 방지 코드
import matplotlib
from matplotlib import font_manager, rc
import platform
if platform.system()=="Windows":
    font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus']=False

import warnings
warnings.filterwarnings("ignore")

# %%
df["공급예비율(%)"].resample('D').mean().plot(title='공급예비율(%) resampled over day for mean', color='darkgreen') 
plt.tight_layout()
plt.show()

df["최대전력(MW)"].resample('D').sum().plot(title='최대전력(MW) resampled over day for sum',color='orange') 
#df.Global_active_power.resample('D').mean().plot(title='Global_active_power resampled over day', color='red') 
plt.tight_layout()
plt.show()   

# data가 day 단위로 sum 되어서 시각화되어짐
# => 하루동안의 전력소비량의 합계가 구해져서 도출되어짐

# %% [markdown]
# ### Below I show mean and std of 'Global_intensity' resampled over day

# %%
# r = data["최대전력(MW)"].resample('D').agg(['mean', 'max'])
# r.plot(subplots = True, title='최대전력(MW) resampled over day')
# plt.show()

# %% [markdown]
# ### Sum of '공급예비율(%)' resampled over month

# %%
r = df["공급예비율(%)"].resample('M').agg(['mean', 'std'])
r.plot(subplots = True, title='공급예비율(%) resampled over day', color='yellow')
plt.show()
# y축 값이 이전의 sum과 다르다 
# mean값이 하루단위로 전력소비량의 평균이 도출됨

# %% [markdown]
# ### Sum of '공급예비율(%)' resampled over month ### bar

# %%
# Sum of 'Global_active_power' resampled over month
df['공급예비율(%)'].resample('M').mean().plot(kind='bar')
plt.xticks(rotation=20)
plt.ylabel('공급예비율(%)')
plt.title('공급예비율(%) per month (averaged over month)')
plt.show()

# %% [markdown]
# ## Mean of '공급예비율(%)' resampled over quarter

# %%
df['공급예비율(%)'].resample('Q').mean().plot(kind='bar')
plt.xticks(rotation=20)
plt.ylabel('공급예비율(%)')
plt.title('공급예비율(%) per quarter (averaged over quarter)')
plt.show()

# %% [markdown]
# ## mean of '최대전력(MW)' resampled over month

# %%
df["최대전력(MW)"].resample('M').mean().plot(kind='bar', color='skyblue')
plt.xticks(rotation=26)
plt.ylabel('최대전력(MW)')
plt.title('최대전력(MW) per Month')
plt.show()

# %%
# df['Sub_metering_1'].resample('M').mean().plot(kind='bar', color='brown')
# plt.xticks(rotation=60)
# plt.ylabel('Sub_metering_1')
# plt.title('Sub_metering_1 per quarter (summed over quarter)')
# plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 259 entries, 2019-09-16 to 2019-01-01
# Data columns (total 6 columns):
# 설비용량(MW)     259 non-null int64
# 공급능력(MW)     259 non-null int64
# 최대전력(MW)     259 non-null int64
# 공급예비력(MW)    259 non-null int64
# 공급예비율(%)     259 non-null float64
# 최대전력기준일시     259 non-null object
# dtypes: float64(1), int64(4), object(1)
# memory usage: 14.2+ KB

# %%
df
# Out:
#             설비용량(MW)  공급능력(MW)  최대전력(MW)  공급예비력(MW)  공급예비율(%)  \
# 최대전력기준일시2
# 2019-09-16    122490     88841     71926      16915      23.5
# 2019-09-15    122490     87737     58401      29336      50.2
# 2019-09-14    122490     87824     55077      32747      59.5
# 2019-09-13    122490     87867     50583      37284      73.7
# 2019-09-12    122490     89300     55025      34275      62.3
# 2019-09-11    122490     92360     73271      19089      26.1
# 2019-09-10    122490     91977     78650      13327      16.9
# 2019-09-09    122973     92717     78980      13737      17.4
# 2019-09-08    122973     92823     65686      27137      41.3
# 2019-09-07    122973     94243     68972      25271      36.6
# 2019-09-06    122973     96032     79916      16116      20.2
# 2019-09-05    122973     96786     79390      17396      21.9
# 2019-09-04    122973     95358     77939      17419      22.3
# 2019-09-03    122973     95152     77067      18085      23.5
# 2019-09-02    122973     96412     76231      20181      26.5
# 2019-09-01    122973     97308     61847      35461      57.3
# 2019-08-31    122973     97968     63393      34575      54.5
# 2019-08-30    122973     99882     73735      26147      35.5
# 2019-08-29    121147     99833     76683      23150      30.2
# 2019-08-28    121147     99232     79037      20195      25.6
# 2019-08-27    121147     99787     77998      21789      27.9
# 2019-08-26    121147     99869     79478      20391      25.7
# 2019-08-25    121147     98253     63326      34927      55.2
# 2019-08-24    121147     98115     64735      33380      51.6
# 2019-08-23    121147    100326     79012      21314      27.0
# 2019-08-22    121147    100471     82264      18207      22.1
# 2019-08-21    121147     99640     83782      15858      18.9
# 2019-08-20    121147     98607     83162      15445      18.6
# 2019-08-19    121147     98558     81590      16968      20.8
# 2019-08-18    121147     96791     66051      30740      46.5
# ...              ...       ...       ...        ...       ...
# 2019-01-30    119350     99728     80741      18987      23.5
# 2019-01-29    119350    100298     81215      19083      23.5
# 2019-01-28    119350     99745     80399      19346      24.1
# 2019-01-27    119350     97470     65189      32281      49.5
# 2019-01-26    119350     97796     68954      28842      41.8
# 2019-01-25    119350     99688     81007      18681      23.1
# 2019-01-24    119350     99535     80239      19296      24.0
# 2019-01-23    119092    100337     80794      19543      24.2
# 2019-01-22    119092    100320     81134      19186      23.6
# 2019-01-21    119092     99530     82668      16862      20.4
# 2019-01-20    119092     99561     65830      33731      51.2
# 2019-01-19    119092     99028     67950      31078      45.7
# 2019-01-18    119092    101500     81668      19832      24.3
# 2019-01-17    119092    101011     82611      18400      22.3
# 2019-01-16    119092    101806     84401      17405      20.6
# 2019-01-15    119092     98347     81378      16969      20.9
# 2019-01-14    119092     98333     81783      16550      20.2
# 2019-01-13    119092     97990     64545      33445      51.8
# 2019-01-12    119092     98303     68147      30156      44.3
# 2019-01-11    119092     99990     81941      18049      22.0
# 2019-01-10    119092    101064     83833      17231      20.6
# 2019-01-09    119092    100827     85392      15435      18.1
# 2019-01-08    119092    100948     83818      17130      20.4
# 2019-01-07    119092    101091     84074      17017      20.2
# 2019-01-06    119092     98748     66493      32255      48.5
# 2019-01-05    119092     99505     69496      30009      43.2
# 2019-01-04    119092    100294     84746      15548      18.3
# 2019-01-03    119092     99695     84196      15499      18.4
# 2019-01-02    119092    101149     82437      18712      22.7
# 2019-01-01    119092    100043     65493      34550      52.8
#
#                      최대전력기준일시
# 최대전력기준일시2
# 2019-09-16  2019/09/16(17:00)
# 2019-09-15  2019/09/15(20:00)
# 2019-09-14  2019/09/14(20:00)
# 2019-09-13  2019/09/13(20:00)
# 2019-09-12  2019/09/12(01:00)
# 2019-09-11  2019/09/11(11:00)
# 2019-09-10  2019/09/10(17:00)
# 2019-09-09  2019/09/09(17:00)
# 2019-09-08  2019/09/08(20:00)
# 2019-09-07  2019/09/07(12:00)
# 2019-09-06  2019/09/06(17:00)
# 2019-09-05  2019/09/05(15:00)
# 2019-09-04  2019/09/04(17:00)
# 2019-09-03  2019/09/03(15:00)
# 2019-09-02  2019/09/02(17:00)
# 2019-09-01  2019/09/01(20:00)
# 2019-08-31  2019/08/31(20:00)
# 2019-08-30  2019/08/30(17:00)
# 2019-08-29  2019/08/29(11:00)
# 2019-08-28  2019/08/28(17:00)
# 2019-08-27  2019/08/27(17:00)
# 2019-08-26  2019/08/26(17:00)
# 2019-08-25  2019/08/25(20:00)
# 2019-08-24  2019/08/24(15:00)
# 2019-08-23  2019/08/23(17:00)
# 2019-08-22  2019/08/22(17:00)
# 2019-08-21  2019/08/21(17:00)
# 2019-08-20  2019/08/20(17:00)
# 2019-08-19  2019/08/19(17:00)
# 2019-08-18  2019/08/18(20:00)
# ...                       ...
# 2019-01-30  2019/01/30(10:00)
# 2019-01-29  2019/01/29(10:00)
# 2019-01-28  2019/01/28(10:00)
# 2019-01-27  2019/01/27(01:00)
# 2019-01-26  2019/01/26(09:00)
# 2019-01-25  2019/01/25(10:00)
# 2019-01-24  2019/01/24(10:00)
# 2019-01-23  2019/01/23(10:00)
# 2019-01-22  2019/01/22(10:00)
# 2019-01-21  2019/01/21(10:00)
# 2019-01-20  2019/01/20(24:00)
# 2019-01-19  2019/01/19(01:00)
# 2019-01-18  2019/01/18(10:00)
# 2019-01-17  2019/01/17(10:00)
# 2019-01-16  2019/01/16(10:00)
# 2019-01-15  2019/01/15(10:00)
# 2019-01-14  2019/01/14(10:00)
# 2019-01-13  2019/01/13(24:00)
# 2019-01-12  2019/01/12(11:00)
# 2019-01-11  2019/01/11(10:00)
# 2019-01-10  2019/01/10(10:00)
# 2019-01-09  2019/01/09(10:00)
# 2019-01-08  2019/01/08(10:00)
# 2019-01-07  2019/01/07(10:00)
# 2019-01-06  2019/01/06(20:00)
# 2019-01-05  2019/01/05(11:00)
# 2019-01-04  2019/01/04(10:00)
# 2019-01-03  2019/01/03(10:00)
# 2019-01-02  2019/01/02(10:00)
# 2019-01-01  2019/01/01(24:00)
#
# [259 rows x 6 columns]

# %%
groups = []
for i in range(0, len(df.columns)):
    groups.append(i)
    print(i)
# groups
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# Below I compare the mean of different featuresresampled over day. 
# specify columns to plot

cols = [0, 1, 2, 3, 4]
i = 1
values = df.resample('M').mean().values
# plot each column
plt.figure(figsize=(15, 10))

for group in groups:
	plt.subplot(len(cols), 1, i)
	plt.plot(values[:, group])
	plt.title(df.columns[group], y=0.75, loc='right')
	i += 1
     
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-c89d78db03ec> in <module>
#       9
#      10 for group in groups:
# ---> 11         plt.subplot(len(cols), 1, i)
#      12         plt.plot(values[:, group])
#      13         plt.title(df.columns[group], y=0.75, loc='right')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1082
#    1083     fig = gcf()
# -> 1084     a = fig.add_subplot(*args, **kwargs)
#    1085     bbox = a.bbox
#    1086     byebye = []
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      58                     raise ValueError(
#      59                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 60                         ).format(maxn=rows*cols, num=num))
#      61                 self._subplotspec = GridSpec(
#      62                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 5, not 6

# %%
df.columns
# Out:
# Index(['설비용량(MW)', '공급능력(MW)', '최대전력(MW)', '공급예비력(MW)', '공급예비율(%)',
#        '최대전력기준일시'],
#       dtype='object')

# %%
## resampling over week and computing mean
df['설비용량(MW)'].resample('W').mean().plot(color='r', legend=True)
df['공급능력(MW)'].resample('W').mean().plot(color='y', legend=True)
df['최대전력(MW)'].resample('W').mean().plot(color='g', legend=True)
df['공급예비력(MW)'].resample('W').mean().plot(color='b', legend=True)
df['공급예비율(%)'].resample('W').mean().plot(color='w', legend=True)
plt.show()

# %%
# Below I show hist plot of the mean of different feature resampled over month 
df['설비용량(MW)'].resample('M').mean().plot(kind='hist', color='r', legend=True )
df['공급능력(MW)'].resample('M').mean().plot(kind='hist',color='y', legend=True)
df['최대전력(MW)'].resample('M').sum().plot(kind='hist',color='g', legend=True)
df['공급예비력(MW)'].resample('M').mean().plot(kind='hist', color='b', legend=True)
df['공급예비율(%)'].resample('M').mean().plot(kind='hist', color='w', legend=True)
plt.show()

# %% [markdown]
# ## The correlations between '설비용량' and  '공급능력'

# %%
# df = df.drop(['최대전력기준일시'], axis=1)

# %%
df.head()
# Out:
#             설비용량(MW)  공급능력(MW)  최대전력(MW)  공급예비력(MW)  공급예비율(%)
# 최대전력기준일시2
# 2019-09-16    122490     88841     71926      16915      23.5
# 2019-09-15    122490     87737     58401      29336      50.2
# 2019-09-14    122490     87824     55077      32747      59.5
# 2019-09-13    122490     87867     50583      37284      73.7
# 2019-09-12    122490     89300     55025      34275      62.3

# %%
data_returns = df.pct_change() # 변화율 산출해주는 함수 
data_returns.head()
# Out:
#             설비용량(MW)  공급능력(MW)  최대전력(MW)  공급예비력(MW)  공급예비율(%)
# 최대전력기준일시2
# 2019-09-16       NaN       NaN       NaN        NaN       NaN
# 2019-09-15       0.0 -0.012427 -0.188040   0.734319  1.136170
# 2019-09-14       0.0  0.000992 -0.056917   0.116274  0.185259
# 2019-09-13       0.0  0.000490 -0.081595   0.138547  0.238655
# 2019-09-12       0.0  0.016309  0.087816  -0.080705 -0.154681

# %%
## The correlations between '설비용량(MW)', y='공급능력(MW)
sns.jointplot(x='설비용량(MW)', y='공급능력(MW)', data=data_returns)  
plt.show()

# %%
## The correlations between '공급예비력(MW)', y='공급예비율(%)'
sns.jointplot(x='공급예비력(MW)', y='공급예비율(%)', data=data_returns)  
plt.show()

# %% [markdown]
# # Correlations among features

# %%
df.columns
# Out:
# Index(['설비용량(MW)', '공급능력(MW)', '최대전력(MW)', '공급예비력(MW)', '공급예비율(%)'], dtype='object')

# %%
# Correlations among columns
plt.matshow(df.corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
plt.title('without resampling', size=15)
plt.colorbar()
plt.show()
#['설비용량(MW)', '공급능력(MW)', '최대전력(MW)', '공급예비력(MW)', '공급예비율(%)']

# %% [markdown]
# # Correlations of mean of resampled features

# %%
# Correlations of mean of features resampled over months

plt.matshow(df.resample('M').mean().corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
plt.title('resampled over month', size=15)
plt.colorbar()
plt.margins(0.02)
plt.matshow(df.resample('Q').mean().corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
plt.title('resampled over quarter', size=15)
plt.colorbar()
plt.show()

# %% [markdown]
# ###  LSTM _ dropout 같은 걸 사용하여 node percentage 설정이 가능하다
# ### Overfitting 부분 처리도 필요
# ### 역정규화 작업 필요
# ### => inverse_transform : 예측값에 대해 정규화이전값으로 도출되어짐

# %% [markdown]
# # Machine-Leaning: LSTM Data Preparation and feature engineering

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	dff = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(dff.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(dff.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
## resampling of data over hour
df_resample = df.resample('h').mean() 
df_resample.shape
# Out:
# (34589, 7)

# %%
## If you would like to train based on the resampled data (over hour), then used below
values = df_resample.values 


## full data without resampling
#values = df.values

# integer encode direction
# ensure all data is float
#values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)

# drop columns we don't want to predict
reframed.drop(reframed.columns[[8,9,10,11,12,13]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.636816   0.295738   0.337945   0.631157        0.0   0.011366
# 2   0.545045   0.103358   0.335501   0.541487        0.0   0.144652
# 3   0.509006   0.110073   0.283802   0.502152        0.0   0.030869
# 4   0.488550   0.096987   0.315987   0.481110        0.0   0.000000
# 5   0.455597   0.099010   0.434417   0.449904        0.0   0.008973
#
#    var7(t-1)   var1(t)
# 1   0.782418  0.545045
# 2   0.782676  0.509006
# 3   0.774169  0.488550
# 4   0.778809  0.455597
# 5   0.798917  0.322555

# %% [markdown]
# # Splitting the rest of data to train and validation sets

# %%
# split into train and test sets
values = reframed.values
n_train_time = 365*24
train = values[:n_train_time, :]
test = values[n_train_time:, :]

##test = values[n_train_time:n_test_time, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape) 

# We reshaped the input into the 3D format as expected by LSTMs, namely [samples, timesteps, features].
# Out:
# (8760, 1, 7) (8760,) (25828, 1, 7) (25828,)

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
#    model.add(LSTM(70))
#    model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=20, batch_size=70, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], 7))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, -6:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_X[:, -6:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0918 10:32:14.472145  1148 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0918 10:32:14.788408  1148 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0918 10:32:14.862721  1148 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0918 10:32:15.769841  1148 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0918 10:32:15.776820  1148 deprecation.py:506] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0918 10:32:15.798753  1148 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0918 10:32:16.185466  1148 deprecation.py:323] From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0918 10:32:16.593487  1148 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 8760 samples, validate on 25828 samples
# Epoch 1/20
#  - 2s - loss: 0.0215 - val_loss: 0.0124
# Epoch 2/20
#  - 0s - loss: 0.0130 - val_loss: 0.0112
# Epoch 3/20
#  - 0s - loss: 0.0118 - val_loss: 0.0101
# Epoch 4/20
#  - 0s - loss: 0.0111 - val_loss: 0.0096
# Epoch 5/20
#  - 0s - loss: 0.0108 - val_loss: 0.0092
# Epoch 6/20
#  - 0s - loss: 0.0106 - val_loss: 0.0092
# Epoch 7/20
#  - 0s - loss: 0.0105 - val_loss: 0.0093
# Epoch 8/20
#  - 0s - loss: 0.0106 - val_loss: 0.0092
# Epoch 9/20
#  - 0s - loss: 0.0106 - val_loss: 0.0092
# Epoch 10/20
#  - 0s - loss: 0.0105 - val_loss: 0.0092
# Epoch 11/20
#  - 0s - loss: 0.0105 - val_loss: 0.0092
# Epoch 12/20
#  - 0s - loss: 0.0104 - val_loss: 0.0092
# Epoch 13/20
#  - 0s - loss: 0.0104 - val_loss: 0.0093
# Epoch 14/20
#  - 0s - loss: 0.0104 - val_loss: 0.0092
# Epoch 15/20
#  - 0s - loss: 0.0104 - val_loss: 0.0091
# Epoch 16/20
#  - 0s - loss: 0.0104 - val_loss: 0.0092
# Epoch 17/20
#  - 0s - loss: 0.0103 - val_loss: 0.0091
# Epoch 18/20
#  - 0s - loss: 0.0104 - val_loss: 0.0092
# Epoch 19/20
#  - 0s - loss: 0.0104 - val_loss: 0.0093
# Epoch 20/20
#  - 0s - loss: 0.0104 - val_loss: 0.0091
# Test RMSE: 0.614
