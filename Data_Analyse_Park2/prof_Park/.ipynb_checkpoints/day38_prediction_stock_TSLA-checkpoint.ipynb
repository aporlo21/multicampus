# %% [markdown]
# ## TSLA 주식값 예측

# %%
import pandas as pd 

# tsla = pd.read_csv('TSLA.csv')
# tsla

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
tf.reset_default_graph()
def MinMaxScaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    # 각 컬럼들에대해서 scaling
    return numerator / denominator

# %%
xy = np.loadtxt('TSLA.csv', delimiter = ",", skiprows = 1)
xy
# xy = xy[::-1] # 역순으로 ... 현재 과거 바꿔 # 표순 역접
# Out:
# array([[3.18000000e+02, 3.22440002e+02, 3.08809998e+02, 1.30793000e+07,
#         3.19269989e+02],
#        [3.18410004e+02, 3.18880005e+02, 3.11190002e+02, 7.64910000e+06,
#         3.11859985e+02],
#        [3.10269989e+02, 3.11850006e+02, 3.03690002e+02, 7.44740000e+06,
#         3.05010010e+02],
#        ...,
#        [2.22009995e+02, 2.23220001e+02, 2.17600006e+02, 7.79430000e+06,
#         2.20830002e+02],
#        [2.22800003e+02, 2.25399994e+02, 2.18220001e+02, 6.55900000e+06,
#         2.22149994e+02],
#        [2.19970001e+02, 2.21169998e+02, 2.11000000e+02, 8.53860000e+06,
#         2.11399994e+02]])

# %%
seq_length = 7

train_size = int(len(xy)*0.7)
train_set = xy[0:train_size] # 0 - 174 # 행번호 # train data
test_set = xy[train_size - seq_length:] # [175 - (7) : ]
data_dim = 5
hidden_dim = 10
learning_rate = 0.01
iterations = 500
output_dim = 1
# 168, 169, 170 - 174 => 175
train_set = MinMaxScaler(train_set)
test_set = MinMaxScaler(test_set)

# %%
def build_dataset(time_series, seq_length):
    dataX = []
    dataY = []
    for i in range(0,len(time_series)-seq_length): # (0,175-7(168)) = 167
        _x = time_series[i:i+seq_length, :] # 일주일 data
        _y = time_series[i+seq_length, [-1]] # _x 에 해당하는 일주일 + 1 (다음날)의 종가
#         print(_x, '=>', _y)
        dataX.append(_x)
        dataY.append(_y)
    return np.array(dataX), np.array(dataY)
        
    # i = traing data 시작일 
trainX, trainY = build_dataset(train_set, seq_length)
testX, testY = build_dataset(test_set, seq_length)
# data[0-174]                   # [7]

# %%
# 그래프초기화
tf.reset_default_graph()

x=tf.placeholder(tf.float32, [None, seq_length, data_dim])
#                                          7         5
y=tf.placeholder(tf.float32, [None, 1])

cell=tf.contrib.rnn.BasicLSTMCell(num_units=hidden_dim, activation=tf.tanh)
outputs, _states=tf.nn.dynamic_rnn(cell, x, dtype=tf.float32)
yHat=tf.contrib.layers.fully_connected(outputs[:,-1],output_dim, activation_fn=None)

cost=tf.reduce_sum(tf.square(yHat-y))
train=tf.train.AdamOptimizer(learning_rate).minimize(cost)

targets=tf.placeholder(tf.float32, [None,1])
predictions=tf.placeholder(tf.float32, [None,1])
rmse=tf.sqrt(tf.reduce_mean(tf.square(targets-predictions)))

# %%
# %matplotlib inline

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(iterations):
        _, cv=sess.run([train, cost], feed_dict={x:trainX, y:trainY})
        print("step:{}, cost:{}".format(i,cv))
    test_predict=sess.run(yHat, feed_dict={x:testX})
    rmse_val=sess.run(rmse, feed_dict={targets:testY, predictions:test_predict})
    print("rmse:{}".format(rmse_val))
    plt.plot(testY)
    plt.plot(test_predict)
    plt.xlabel("time")
    plt.ylabel("stock price")
    plt.show()
# Out:
# step:0, cost:28.735618591308594
# step:1, cost:13.242511749267578
# step:2, cost:5.3892412185668945
# step:3, cost:4.846599578857422
# step:4, cost:7.880237579345703
# step:5, cost:8.891674041748047
# step:6, cost:7.433208465576172
# step:7, cost:5.2401347160339355
# step:8, cost:3.630091667175293
# step:9, cost:3.0732803344726562
# step:10, cost:3.373849391937256
# step:11, cost:3.9710140228271484
# step:12, cost:4.345303535461426
# step:13, cost:4.278545379638672
# step:14, cost:3.8234593868255615
# step:15, cost:3.1773054599761963
# step:16, cost:2.567990303039551
# step:17, cost:2.1706247329711914
# step:18, cost:2.055297374725342
# step:19, cost:2.1714725494384766
# step:20, cost:2.3780245780944824
# step:21, cost:2.515779495239258
# step:22, cost:2.4888339042663574
# step:23, cost:2.304658889770508
# step:24, cost:2.0519347190856934
# step:25, cost:1.8402609825134277
# step:26, cost:1.742397427558899
# step:27, cost:1.766384482383728
# step:28, cost:1.8633842468261719
# step:29, cost:1.9603135585784912
# step:30, cost:1.9979889392852783
# step:31, cost:1.95648193359375
# step:32, cost:1.8581998348236084
# step:33, cost:1.7508031129837036
# step:34, cost:1.6804251670837402
# step:35, cost:1.6683886051177979
# step:36, cost:1.7024226188659668
# step:37, cost:1.746685266494751
# step:38, cost:1.7646148204803467
# step:39, cost:1.7402665615081787
# step:40, cost:1.6848756074905396
# step:41, cost:1.626222848892212
# step:42, cost:1.589800238609314
# step:43, cost:1.5842623710632324
# step:44, cost:1.5988924503326416
# step:45, cost:1.612766981124878
# step:46, cost:1.6087822914123535
# step:47, cost:1.5836241245269775
# step:48, cost:1.547979712486267
# step:49, cost:1.517906904220581
# step:50, cost:1.5037987232208252
# step:51, cost:1.504307508468628
# step:52, cost:1.5087591409683228
# step:53, cost:1.5056602954864502
# step:54, cost:1.4908850193023682
# step:55, cost:1.4697809219360352
# step:56, cost:1.4522054195404053
# step:57, cost:1.4446223974227905
# step:58, cost:1.4453294277191162
# step:59, cost:1.4464309215545654
# step:60, cost:1.440826654434204
# step:61, cost:1.4281049966812134
# step:62, cost:1.4141689538955688
# step:63, cost:1.4053343534469604
# step:64, cost:1.4026949405670166
# step:65, cost:1.4018081426620483
# step:66, cost:1.3974449634552002
# step:67, cost:1.3885383605957031
# step:68, cost:1.3786966800689697
# step:69, cost:1.3721717596054077
# step:70, cost:1.369542121887207
# step:71, cost:1.3674933910369873
# step:72, cost:1.362710952758789
# step:73, cost:1.3554093837738037
# step:74, cost:1.3486477136611938
# step:75, cost:1.34462308883667
# step:76, cost:1.342396855354309
# step:77, cost:1.339393973350525
# step:78, cost:1.334517002105713
# step:79, cost:1.3291678428649902
# step:80, cost:1.3252769708633423
# step:81, cost:1.3229584693908691
# step:82, cost:1.320600986480713
# step:83, cost:1.3170249462127686
# step:84, cost:1.3128366470336914
# step:85, cost:1.3093998432159424
# step:86, cost:1.3070260286331177
# step:87, cost:1.3047488927841187
# step:88, cost:1.3017250299453735
# step:89, cost:1.298269510269165
# step:90, cost:1.295264482498169
# step:91, cost:1.2929298877716064
# step:92, cost:1.2906335592269897
# step:93, cost:1.2878485918045044
# step:94, cost:1.2848334312438965
# step:95, cost:1.2821608781814575
# step:96, cost:1.2799018621444702
# step:97, cost:1.2776165008544922
# step:98, cost:1.275033950805664
# step:99, cost:1.2723926305770874
# step:100, cost:1.2700283527374268
# step:101, cost:1.2678943872451782
# step:102, cost:1.265688419342041
# step:103, cost:1.2633168697357178
# step:104, cost:1.2609903812408447
# step:105, cost:1.2588729858398438
# step:106, cost:1.2568554878234863
# step:107, cost:1.254755973815918
# step:108, cost:1.2525908946990967
# step:109, cost:1.250515103340149
# step:110, cost:1.2485730648040771
# step:111, cost:1.2466518878936768
# step:112, cost:1.2446718215942383
# step:113, cost:1.2426977157592773
# step:114, cost:1.2408158779144287
# step:115, cost:1.2390021085739136
# step:116, cost:1.2371747493743896
# step:117, cost:1.2353252172470093
# step:118, cost:1.2335171699523926
# step:119, cost:1.2317763566970825
# step:120, cost:1.2300572395324707
# step:121, cost:1.2283236980438232
# step:122, cost:1.226601243019104
# step:123, cost:1.2249256372451782
# step:124, cost:1.2232837677001953
# step:125, cost:1.2216416597366333
# step:126, cost:1.2199981212615967
# step:127, cost:1.2183809280395508
# step:128, cost:1.2167960405349731
# step:129, cost:1.215221881866455
# step:130, cost:1.2136471271514893
# step:131, cost:1.2120862007141113
# step:132, cost:1.2105509042739868
# step:133, cost:1.2090309858322144
# step:134, cost:1.2075133323669434
# step:135, cost:1.2060036659240723
# step:136, cost:1.2045130729675293
# step:137, cost:1.2030389308929443
# step:138, cost:1.2015705108642578
# step:139, cost:1.2001088857650757
# step:140, cost:1.1986616849899292
# step:141, cost:1.1972295045852661
# step:142, cost:1.195805311203003
# step:143, cost:1.1943869590759277
# step:144, cost:1.1929799318313599
# step:145, cost:1.1915862560272217
# step:146, cost:1.190201759338379
# step:147, cost:1.1888238191604614
# step:148, cost:1.1874557733535767
# step:149, cost:1.1860991716384888
# step:150, cost:1.1847518682479858
# step:151, cost:1.1834113597869873
# step:152, cost:1.1820801496505737
# step:153, cost:1.1807589530944824
# step:154, cost:1.1794471740722656
# step:155, cost:1.1781426668167114
# step:156, cost:1.1768467426300049
# step:157, cost:1.175560474395752
# step:158, cost:1.1742830276489258
# step:159, cost:1.1730133295059204
# step:160, cost:1.171751856803894
# step:161, cost:1.1704992055892944
# step:162, cost:1.169255256652832
# step:163, cost:1.1680190563201904
# step:164, cost:1.1667912006378174
# step:165, cost:1.165571689605713
# step:166, cost:1.1643606424331665
# step:167, cost:1.1631572246551514
# step:168, cost:1.1619622707366943
# step:169, cost:1.1607754230499268
# step:170, cost:1.1595966815948486
# step:171, cost:1.1584258079528809
# step:172, cost:1.1572628021240234
# step:173, cost:1.1561081409454346
# step:174, cost:1.154961347579956
# step:175, cost:1.153822422027588
# step:176, cost:1.1526916027069092
# step:177, cost:1.1515684127807617
# step:178, cost:1.1504534482955933
# step:179, cost:1.149346113204956
# step:180, cost:1.1482462882995605
# step:181, cost:1.1471548080444336
# step:182, cost:1.1460707187652588
# step:183, cost:1.1449942588806152
# step:184, cost:1.1439259052276611
# step:185, cost:1.1428649425506592
# step:186, cost:1.141811728477478
# step:187, cost:1.1407661437988281
# step:188, cost:1.13972806930542
# step:189, cost:1.1386979818344116
# step:190, cost:1.1376750469207764
# step:191, cost:1.136659860610962
# step:192, cost:1.1356520652770996
# step:193, cost:1.1346516609191895
# step:194, cost:1.133658766746521
# step:195, cost:1.1326732635498047
# step:196, cost:1.1316951513290405
# step:197, cost:1.1307244300842285
# step:198, cost:1.129760980606079
# step:199, cost:1.1288045644760132
# step:200, cost:1.1278555393218994
# step:201, cost:1.1269139051437378
# step:202, cost:1.1259794235229492
# step:203, cost:1.125051736831665
# step:204, cost:1.1241313219070435
# step:205, cost:1.123218059539795
# step:206, cost:1.1223115921020508
# step:207, cost:1.1214123964309692
# step:208, cost:1.1205198764801025
# step:209, cost:1.1196343898773193
# step:210, cost:1.1187556982040405
# step:211, cost:1.1178839206695557
# step:212, cost:1.117018699645996
# step:213, cost:1.1161603927612305
# step:214, cost:1.1153087615966797
# step:215, cost:1.1144636869430542
# step:216, cost:1.1136250495910645
# step:217, cost:1.1127933263778687
# step:218, cost:1.1119678020477295
# step:219, cost:1.1111485958099365
# step:220, cost:1.1103363037109375
# step:221, cost:1.1095302104949951
# step:222, cost:1.1087300777435303
# step:223, cost:1.1079362630844116
# step:224, cost:1.10714852809906
# step:225, cost:1.1063672304153442
# step:226, cost:1.1055917739868164
# step:227, cost:1.1048223972320557
# step:228, cost:1.1040592193603516
# step:229, cost:1.1033015251159668
# step:230, cost:1.1025499105453491
# step:231, cost:1.1018041372299194
# step:232, cost:1.1010639667510986
# step:233, cost:1.1003293991088867
# step:234, cost:1.0996005535125732
# step:235, cost:1.0988773107528687
# step:236, cost:1.0981593132019043
# step:237, cost:1.0974469184875488
# step:238, cost:1.0967397689819336
# step:239, cost:1.0960379838943481
# step:240, cost:1.095341444015503
# step:241, cost:1.0946497917175293
# step:242, cost:1.0939631462097168
# step:243, cost:1.0932817459106445
# step:244, cost:1.0926053524017334
# step:245, cost:1.0919337272644043
# step:246, cost:1.0912668704986572
# step:247, cost:1.0906046628952026
# step:248, cost:1.0899474620819092
# step:249, cost:1.08929443359375
# step:250, cost:1.0886461734771729
# step:251, cost:1.08800208568573
# step:252, cost:1.08736252784729
# step:253, cost:1.0867271423339844
# step:254, cost:1.0860960483551025
# step:255, cost:1.085469126701355
# step:256, cost:1.0848462581634521
# step:257, cost:1.084227204322815
# step:258, cost:1.0836122035980225
# step:259, cost:1.083000898361206
# step:260, cost:1.0823935270309448
# step:261, cost:1.0817897319793701
# step:262, cost:1.0811896324157715
# step:263, cost:1.0805926322937012
# step:264, cost:1.0799994468688965
# step:265, cost:1.0794093608856201
# step:266, cost:1.0788228511810303
# step:267, cost:1.0782394409179688
# step:268, cost:1.077659010887146
# step:269, cost:1.0770817995071411
# step:270, cost:1.076507568359375
# step:271, cost:1.0759360790252686
# step:272, cost:1.0753674507141113
# step:273, cost:1.0748016834259033
# step:274, cost:1.0742385387420654
# step:275, cost:1.0736780166625977
# step:276, cost:1.073119878768921
# step:277, cost:1.0725641250610352
# step:278, cost:1.0720107555389404
# step:279, cost:1.0714598894119263
# step:280, cost:1.070910930633545
# step:281, cost:1.0703644752502441
# step:282, cost:1.069819688796997
# step:283, cost:1.0692771673202515
# step:284, cost:1.0687364339828491
# step:285, cost:1.0681976079940796
# step:286, cost:1.0676604509353638
# step:287, cost:1.0671252012252808
# step:288, cost:1.0665912628173828
# step:289, cost:1.0660591125488281
# step:290, cost:1.065528392791748
# step:291, cost:1.0649993419647217
# step:292, cost:1.06447172164917
# step:293, cost:1.0639448165893555
# step:294, cost:1.0634195804595947
# step:295, cost:1.0628952980041504
# step:296, cost:1.0623722076416016
# step:297, cost:1.0618501901626587
# step:298, cost:1.0613290071487427
# step:299, cost:1.0608088970184326
# step:300, cost:1.0602898597717285
# step:301, cost:1.0597712993621826
# step:302, cost:1.059253454208374
# step:303, cost:1.0587365627288818
# step:304, cost:1.0582200288772583
# step:305, cost:1.0577040910720825
# step:306, cost:1.0571887493133545
# step:307, cost:1.0566737651824951
# step:308, cost:1.0561593770980835
# step:309, cost:1.0556449890136719
# step:310, cost:1.055131196975708
# step:311, cost:1.0546176433563232
# step:312, cost:1.0541040897369385
# step:313, cost:1.0535908937454224
# step:314, cost:1.0530774593353271
# step:315, cost:1.052564263343811
# step:316, cost:1.052051305770874
# step:317, cost:1.0515379905700684
# step:318, cost:1.0510244369506836
# step:319, cost:1.0505108833312988
# step:320, cost:1.049997091293335
# step:321, cost:1.049483060836792
# step:322, cost:1.048969030380249
# step:323, cost:1.0484540462493896
# step:324, cost:1.0479390621185303
# step:325, cost:1.0474238395690918
# step:326, cost:1.0469077825546265
# step:327, cost:1.0463913679122925
# step:328, cost:1.0458742380142212
# step:329, cost:1.0453567504882812
# step:330, cost:1.0448384284973145
# step:331, cost:1.044319748878479
# step:332, cost:1.0438001155853271
# step:333, cost:1.0432796478271484
# step:334, cost:1.0427584648132324
# step:335, cost:1.0422364473342896
# step:336, cost:1.0417135953903198
# step:337, cost:1.0411897897720337
# step:338, cost:1.0406652688980103
# step:339, cost:1.0401394367218018
# step:340, cost:1.0396127700805664
# step:341, cost:1.0390849113464355
# step:342, cost:1.0385558605194092
# step:343, cost:1.038025975227356
# step:344, cost:1.0374945402145386
# step:345, cost:1.0369622707366943
# step:346, cost:1.0364288091659546
# step:347, cost:1.0358937978744507
# step:348, cost:1.0353574752807617
# step:349, cost:1.0348198413848877
# step:350, cost:1.0342810153961182
# step:351, cost:1.033740758895874
# step:352, cost:1.0331990718841553
# step:353, cost:1.0326558351516724
# step:354, cost:1.0321110486984253
# step:355, cost:1.0315648317337036
# step:356, cost:1.0310173034667969
# step:357, cost:1.0304676294326782
# step:358, cost:1.029916524887085
# step:359, cost:1.029363751411438
# step:360, cost:1.0288095474243164
# step:361, cost:1.0282535552978516
# step:362, cost:1.0276957750320435
# step:363, cost:1.0271363258361816
# step:364, cost:1.026574969291687
# step:365, cost:1.0260114669799805
# step:366, cost:1.0254464149475098
# step:367, cost:1.0248796939849854
# step:368, cost:1.0243109464645386
# step:369, cost:1.023740291595459
# step:370, cost:1.0231677293777466
# step:371, cost:1.0225930213928223
# step:372, cost:1.0220165252685547
# step:373, cost:1.0214378833770752
# step:374, cost:1.0208572149276733
# step:375, cost:1.02027428150177
# step:376, cost:1.0196895599365234
# step:377, cost:1.0191025733947754
# step:378, cost:1.0185134410858154
# step:379, cost:1.0179226398468018
# step:380, cost:1.0173289775848389
# step:381, cost:1.0167334079742432
# step:382, cost:1.016135811805725
# step:383, cost:1.015535831451416
# step:384, cost:1.014933466911316
# step:385, cost:1.014329195022583
# step:386, cost:1.0137226581573486
# step:387, cost:1.0131134986877441
# step:388, cost:1.0125024318695068
# step:389, cost:1.0118889808654785
# step:390, cost:1.0112731456756592
# step:391, cost:1.0106548070907593
# step:392, cost:1.010034441947937
# step:393, cost:1.0094118118286133
# step:394, cost:1.0087864398956299
# step:395, cost:1.0081591606140137
# step:396, cost:1.0075291395187378
# step:397, cost:1.006897211074829
# step:398, cost:1.0062625408172607
# step:399, cost:1.0056257247924805
# step:400, cost:1.0049864053726196
# step:401, cost:1.0043447017669678
# step:402, cost:1.0037007331848145
# step:403, cost:1.0030546188354492
# step:404, cost:1.0024058818817139
# step:405, cost:1.0017547607421875
# step:406, cost:1.0011014938354492
# step:407, cost:1.0004456043243408
# step:408, cost:0.9997876882553101
# step:409, cost:0.999127209186554
# step:410, cost:0.9984646439552307
# step:411, cost:0.9977993965148926
# step:412, cost:0.9971320629119873
# step:413, cost:0.9964624643325806
# step:414, cost:0.9957903027534485
# step:415, cost:0.9951162338256836
# step:416, cost:0.9944398999214172
# step:417, cost:0.993760883808136
# step:418, cost:0.9930799603462219
# step:419, cost:0.9923965930938721
# step:420, cost:0.9917111396789551
# step:421, cost:0.9910235404968262
# step:422, cost:0.9903334379196167
# step:423, cost:0.9896414279937744
# step:424, cost:0.9889470338821411
# step:425, cost:0.9882508516311646
# step:426, cost:0.9875520467758179
# step:427, cost:0.9868515133857727
# step:428, cost:0.9861485958099365
# step:429, cost:0.9854435920715332
# step:430, cost:0.9847366213798523
# step:431, cost:0.9840274453163147
# step:432, cost:0.98331618309021
# step:433, cost:0.9826028347015381
# step:434, cost:0.9818876385688782
# step:435, cost:0.9811699390411377
# step:436, cost:0.9804506301879883
# step:437, cost:0.9797288775444031
# step:438, cost:0.9790053367614746
# step:439, cost:0.978279709815979
# step:440, cost:0.9775518774986267
# step:441, cost:0.9768221378326416
# step:442, cost:0.9760904908180237
# step:443, cost:0.9753567576408386
# step:444, cost:0.9746208190917969
# step:445, cost:0.9738828539848328
# step:446, cost:0.9731429815292358
# step:447, cost:0.9724009037017822
# step:448, cost:0.9716567993164062
# step:449, cost:0.9709107279777527
# step:450, cost:0.9701623916625977
# step:451, cost:0.9694120287895203
# step:452, cost:0.9686594009399414
# step:453, cost:0.9679051041603088
# step:454, cost:0.9671481847763062
# step:455, cost:0.9663892984390259
# step:456, cost:0.9656280875205994
# step:457, cost:0.96486496925354
# step:458, cost:0.964099645614624
# step:459, cost:0.9633318185806274
# step:460, cost:0.9625619649887085
# step:461, cost:0.9617896676063538
# step:462, cost:0.9610151052474976
# step:463, cost:0.9602380990982056
# step:464, cost:0.9594589471817017
# step:465, cost:0.9586772918701172
# step:466, cost:0.9578932523727417
# step:467, cost:0.9571070075035095
# step:468, cost:0.9563181400299072
# step:469, cost:0.9555269479751587
# step:470, cost:0.9547332525253296
# step:471, cost:0.9539369344711304
# step:472, cost:0.9531381130218506
# step:473, cost:0.9523369073867798
# step:474, cost:0.9515329599380493
# step:475, cost:0.9507265090942383
# step:476, cost:0.9499176740646362
# step:477, cost:0.9491061568260193
# step:478, cost:0.948292076587677
# step:479, cost:0.9474750757217407
# step:480, cost:0.9466556906700134
# step:481, cost:0.9458337426185608
# step:482, cost:0.9450088739395142
# step:483, cost:0.9441815614700317
# step:484, cost:0.9433518648147583
# step:485, cost:0.9425192475318909
# step:486, cost:0.9416839480400085
# step:487, cost:0.9408462643623352
# step:488, cost:0.9400060176849365
# step:489, cost:0.9391629695892334
# step:490, cost:0.9383174180984497
# step:491, cost:0.9374693632125854
# step:492, cost:0.9366188049316406
# step:493, cost:0.9357658624649048
# step:494, cost:0.9349104762077332
# step:495, cost:0.9340524673461914
# step:496, cost:0.933192253112793
# step:497, cost:0.932329535484314
# step:498, cost:0.931464433670044
# step:499, cost:0.9305974245071411
# rmse:0.08971388638019562
