# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import missingno as msno
from plotnine import *
from jupyterthemes import jtplot
jtplot.style(theme='gruvboxd', context='paper', spines=True, 
             ticks=True, grid=True, gridlines='dotted', figsize=(6,4.5))

# %%
# decision Tree
train=pd.read_csv("data/train.csv")
test=pd.read_csv("data/test.csv")

# %%
train.describe()
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train['Age_mean']=train['Age'] # 파생변수 = train 모델 | test 모델도 적용가능
train['Age_mean'].fillna(train['Age_mean'].mean(),inplace=True)
test['Age_mean']=test['Age'] # 파생변수 = train 모델 | test 모델도 적용가능
test['Age_mean'].fillna(test['Age_mean'].mean(),inplace=True) # null값 삭제되고 평균값으로 도출

# %%
test['Age_mean'].isnull().sum()
# Out:
# 0

# %%
train['Age_mean'].mean()
print(train['Age_mean'].mean())
# Out:
# 29.699117647058763

# %%
# 함수 // 레이블 인코더 & 핫 인코딩 
train['Sex'].value_counts()
train['Gender']=(train['Sex']=='famale')
test['Gender']=(train['Sex']=='famale')
# 문자형 => bullin 형 변환

# %%
train['Embarked'].value_counts()
test['Embarked'].value_counts()
# value_counts 하면 NaN 값 안나오므로 유무 확인 직접적 불가능
# NaN 확인하려면 isnull().sum()값 확인 
train['Embarked'].isnull().sum()
test['Embarked'].isnull().sum()
print(train['Embarked'].isnull().sum())
print(test['Embarked'].isnull().sum())
# Out:
# 2
# 0

# %%
# 'Embarked' 이가 s,c,q 문자형 => 수치형 변환 필요 // ohe 필요
train['Embarked_S']=train['Embarked']=='S' 
train['Embarked_C']=train['Embarked']=='C' 
train['Embarked_Q']=train['Embarked']=='Q' 
# S:100, C:010, Q:001
# 속성 값이 s 와 같으면 true 반환 (Bullin형)

# %%
train['Embarked'].value_counts()
train['Embarked_S'].sum()
# Out:
# 644

# %%
train[['Embarked_S','Embarked_C','Embarked_Q']] # OHE
# Out:
#      Embarked_S  Embarked_C  Embarked_Q
# 0          True       False       False
# 1         False        True       False
# 2          True       False       False
# 3          True       False       False
# 4          True       False       False
# 5         False       False        True
# 6          True       False       False
# 7          True       False       False
# 8          True       False       False
# 9         False        True       False
# 10         True       False       False
# 11         True       False       False
# 12         True       False       False
# 13         True       False       False
# 14         True       False       False
# 15         True       False       False
# 16        False       False        True
# 17         True       False       False
# 18         True       False       False
# 19        False        True       False
# 20         True       False       False
# 21         True       False       False
# 22        False       False        True
# 23         True       False       False
# 24         True       False       False
# 25         True       False       False
# 26        False        True       False
# 27         True       False       False
# 28        False       False        True
# 29         True       False       False
# ..          ...         ...         ...
# 861        True       False       False
# 862        True       False       False
# 863        True       False       False
# 864        True       False       False
# 865        True       False       False
# 866       False        True       False
# 867        True       False       False
# 868        True       False       False
# 869        True       False       False
# 870        True       False       False
# 871        True       False       False
# 872        True       False       False
# 873        True       False       False
# 874       False        True       False
# 875       False        True       False
# 876        True       False       False
# 877        True       False       False
# 878        True       False       False
# 879       False        True       False
# 880        True       False       False
# 881        True       False       False
# 882        True       False       False
# 883        True       False       False
# 884        True       False       False
# 885       False       False        True
# 886        True       False       False
# 887        True       False       False
# 888        True       False       False
# 889       False        True       False
# 890       False       False        True
#
# [891 rows x 3 columns]

# %%
test['Embarked_S']=test['Embarked']=='S' 
test['Embarked_C']=test['Embarked']=='C' 
test['Embarked_Q']=test['Embarked']=='Q'

# %%
train['FamilySize']=train['SibSp']+train['Parch']+1 # 1: 나까지 포함
# 형제자매 와 사촌의 수 칼럼 + 1 => 전체가족의 수 개체 생성 
# 부가적 파생변수 칼럼 생성하여라 (tip)
train['FamilySize'].value_counts()
# Out:
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: FamilySize, dtype: int64

# %%
# 타이타닉 데이터 .. '나'는 없다 
# 대가족 L(5명) 중가족 M(2~4명) 소가족 S(1명) 
# (구간화하여 => 모델생성 // 파생변수 생성 가능 )
train['Family']=train['FamilySize']
# train['Family']
train.loc[train['FamilySize']==1,'Family']='S'
# 해당 패밀리 군 개체수가 1 인 소가족 family 열의 값 도출 및 참조
train.loc[(train['FamilySize']>1)&(train['FamilySize']<5),'Family']='M'
train.loc[train['FamilySize']>4,'Family']='L'
train[['Family','FamilySize']]
# Out:
#     Family  FamilySize
# 0        M           2
# 1        M           2
# 2        S           1
# 3        M           2
# 4        S           1
# 5        S           1
# 6        S           1
# 7        L           5
# 8        M           3
# 9        M           2
# 10       M           3
# 11       S           1
# 12       S           1
# 13       L           7
# 14       S           1
# 15       S           1
# 16       L           6
# 17       S           1
# 18       M           2
# 19       S           1
# 20       S           1
# 21       S           1
# 22       S           1
# 23       S           1
# 24       L           5
# 25       L           7
# 26       S           1
# 27       L           6
# 28       S           1
# 29       S           1
# ..     ...         ...
# 861      M           2
# 862      S           1
# 863      L          11
# 864      S           1
# 865      S           1
# 866      M           2
# 867      S           1
# 868      S           1
# 869      M           3
# 870      S           1
# 871      M           3
# 872      S           1
# 873      S           1
# 874      M           2
# 875      S           1
# 876      S           1
# 877      S           1
# 878      S           1
# 879      M           2
# 880      M           2
# 881      S           1
# 882      S           1
# 883      S           1
# 884      S           1
# 885      L           6
# 886      S           1
# 887      S           1
# 888      M           4
# 889      S           1
# 890      S           1
#
# [891 rows x 2 columns]

# %%
train['Family_S']=train['Family']=='S'
train['Family_M']=train['Family']=='M'
train['Family_L']=train['Family']=='L'
train[['Family_S','Family_M','Family_L','Family','FamilySize']] 
# OHE also
# Out:
#      Family_S  Family_M  Family_L Family  FamilySize
# 0       False      True     False      M           2
# 1       False      True     False      M           2
# 2        True     False     False      S           1
# 3       False      True     False      M           2
# 4        True     False     False      S           1
# 5        True     False     False      S           1
# 6        True     False     False      S           1
# 7       False     False      True      L           5
# 8       False      True     False      M           3
# 9       False      True     False      M           2
# 10      False      True     False      M           3
# 11       True     False     False      S           1
# 12       True     False     False      S           1
# 13      False     False      True      L           7
# 14       True     False     False      S           1
# 15       True     False     False      S           1
# 16      False     False      True      L           6
# 17       True     False     False      S           1
# 18      False      True     False      M           2
# 19       True     False     False      S           1
# 20       True     False     False      S           1
# 21       True     False     False      S           1
# 22       True     False     False      S           1
# 23       True     False     False      S           1
# 24      False     False      True      L           5
# 25      False     False      True      L           7
# 26       True     False     False      S           1
# 27      False     False      True      L           6
# 28       True     False     False      S           1
# 29       True     False     False      S           1
# ..        ...       ...       ...    ...         ...
# 861     False      True     False      M           2
# 862      True     False     False      S           1
# 863     False     False      True      L          11
# 864      True     False     False      S           1
# 865      True     False     False      S           1
# 866     False      True     False      M           2
# 867      True     False     False      S           1
# 868      True     False     False      S           1
# 869     False      True     False      M           3
# 870      True     False     False      S           1
# 871     False      True     False      M           3
# 872      True     False     False      S           1
# 873      True     False     False      S           1
# 874     False      True     False      M           2
# 875      True     False     False      S           1
# 876      True     False     False      S           1
# 877      True     False     False      S           1
# 878      True     False     False      S           1
# 879     False      True     False      M           2
# 880     False      True     False      M           2
# 881      True     False     False      S           1
# 882      True     False     False      S           1
# 883      True     False     False      S           1
# 884      True     False     False      S           1
# 885     False     False      True      L           6
# 886      True     False     False      S           1
# 887      True     False     False      S           1
# 888     False      True     False      M           4
# 889      True     False     False      S           1
# 890      True     False     False      S           1
#
# [891 rows x 5 columns]

# %%
test['FamilySize']=test['SibSp']+test['Parch']+1 # 1: 나까지 포함
test['Family']=test['FamilySize']
test.loc[test['FamilySize']==1,'Family']='S'
test.loc[(test['FamilySize']>1)&(test['FamilySize']<5),'Family']='M'
test.loc[test['FamilySize']>4,'Family']='L'
test[['Family','FamilySize']]
test['Family_S']=test['Family']=='S'
test['Family_M']=test['Family']=='M'
test['Family_L']=test['Family']=='L'
test[['Family_S','Family_M','Family_L','Family','FamilySize']]
# Out:
#      Family_S  Family_M  Family_L Family  FamilySize
# 0        True     False     False      S           1
# 1       False      True     False      M           2
# 2        True     False     False      S           1
# 3        True     False     False      S           1
# 4       False      True     False      M           3
# 5        True     False     False      S           1
# 6        True     False     False      S           1
# 7       False      True     False      M           3
# 8        True     False     False      S           1
# 9       False      True     False      M           3
# 10       True     False     False      S           1
# 11       True     False     False      S           1
# 12      False      True     False      M           2
# 13      False      True     False      M           2
# 14      False      True     False      M           2
# 15      False      True     False      M           2
# 16       True     False     False      S           1
# 17       True     False     False      S           1
# 18      False      True     False      M           2
# 19       True     False     False      S           1
# 20      False      True     False      M           2
# 21      False      True     False      M           2
# 22       True     False     False      S           1
# 23      False      True     False      M           2
# 24      False     False      True      L           5
# 25      False      True     False      M           2
# 26      False      True     False      M           2
# 27       True     False     False      S           1
# 28       True     False     False      S           1
# 29      False      True     False      M           3
# ..        ...       ...       ...    ...         ...
# 388      True     False     False      S           1
# 389     False     False      True      L           5
# 390      True     False     False      S           1
# 391     False      True     False      M           2
# 392     False      True     False      M           3
# 393      True     False     False      S           1
# 394     False     False      True      L           5
# 395     False      True     False      M           2
# 396      True     False     False      S           1
# 397     False      True     False      M           3
# 398      True     False     False      S           1
# 399      True     False     False      S           1
# 400      True     False     False      S           1
# 401     False      True     False      M           2
# 402     False      True     False      M           2
# 403      True     False     False      S           1
# 404     False      True     False      M           2
# 405      True     False     False      S           1
# 406     False      True     False      M           2
# 407     False      True     False      M           3
# 408      True     False     False      S           1
# 409     False      True     False      M           3
# 410      True     False     False      S           1
# 411     False      True     False      M           2
# 412      True     False     False      S           1
# 413      True     False     False      S           1
# 414      True     False     False      S           1
# 415      True     False     False      S           1
# 416      True     False     False      S           1
# 417     False      True     False      M           3
#
# [418 rows x 5 columns]

# %%
train.head()
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin  ... Age_mean  Gender  \
# 0  34.5      0      0   330911   7.8292   NaN  ...     34.5   False
# 1  47.0      1      0   363272   7.0000   NaN  ...     47.0   False
# 2  62.0      0      0   240276   9.6875   NaN  ...     62.0   False
# 3  27.0      0      0   315154   8.6625   NaN  ...     27.0   False
# 4  22.0      1      1  3101298  12.2875   NaN  ...     22.0   False
#
#    Embarked_S  Embarked_C  Embarked_Q  FamilySize  Family Family_S  Family_M  \
# 0       False       False        True           1       S     True     False
# 1        True       False       False           2       M    False      True
# 2       False       False        True           1       S     True     False
# 3        True       False       False           1       S     True     False
# 4        True       False       False           3       M    False      True
#
#    Family_L
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#
# [5 rows x 21 columns]

# %%
# Pclass[ 수치형 ] => 범주형
train['Pclass'].dtypes
# Out:
# dtype('int64')

# %%
train['Pclass']=train['Pclass'].astype('category')
train['Pclass'].dtypes
# Out:
# CategoricalDtype(categories=[1, 2, 3], ordered=False)

# %%
# FeatureName
fn=['Gender', 'Age_mean', 
    'Embarked_S','Embarked_C','Embarked_Q',
    'Family_S','Family_M','Family_L']
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 22 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null category
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Age_mean       891 non-null float64
# Gender         891 non-null bool
# Embarked_S     891 non-null bool
# Embarked_C     891 non-null bool
# Embarked_Q     891 non-null bool
# FamilySize     891 non-null int64
# Family         891 non-null object
# Family_S       891 non-null bool
# Family_M       891 non-null bool
# Family_L       891 non-null bool
# dtypes: bool(7), category(1), float64(3), int64(5), object(6)
# memory usage: 104.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 22 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# Age_mean       418 non-null float64
# Gender         418 non-null bool
# Embarked_S     418 non-null bool
# Embarked_C     418 non-null bool
# Embarked_Q     418 non-null bool
# FamilySize     418 non-null int64
# Family         418 non-null object
# Family_S       418 non-null bool
# Family_M       418 non-null bool
# Family_L       418 non-null bool
# Survived       418 non-null int64
# dtypes: bool(7), float64(3), int64(6), object(6)
# memory usage: 51.9+ KB

# %%
# train data 의 입력과 출력
# 예측 대상 y 
X_train=train[fn]
# X_train.head()
y_label=train['Survived']
X_test=test[fn] 
# 모델링 [Decision Tree]
from sklearn.tree import DecisionTreeClassifier
# tree 서브 패키지 # Regressort [회귀 - 예측] 모델 도 적용가능
model=DecisionTreeClassifier(max_depth=10) #default - 3 or 5 // 킬람 3개만 바
# 변수가 많을 시 연산량이 방대해지므로 칼럼수를 줄여준다 
# 객체 생성(model)
model # criterion = 'gini' # 불순도 

## 실제 모델 생성 ## 
model.fit(X_train, y_label) 
# 모델 트리 생성 완료
# => 다수의 트리 : 숲 (Random Forest)

# 엔트로피 계산 [분류이전] - (각각의 컬럼으로 나누었을때)
# 얻을 수 있는 IG [분류한 이후]
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.model_selection import KFold, cross_val_score
kfold=KFold(n_splits=10, shuffle=True, random_state=2019)
kfold
# Out:
# KFold(n_splits=10, random_state=2019, shuffle=True)

# %%
score=cross_val_score(model, X_train, y_label, cv=kfold, 
                      scoring='accuracy') 
print(score)
# (model 객체, x, y, cv=kfold)
round(np.mean(score)*100,2)
# Out:
# [0.6        0.5505618  0.70786517 0.60674157 0.73033708 0.71910112
#  0.52808989 0.64044944 0.76404494 0.5505618 ]
# 63.98

# %%
prediction=model.predict(X_test)
prediction.shape
# 0 - 죽음 # 1 - 삶
# 열개의 컬럼 중 90건씩 들어가있는 데이터에 대해서 첫번째 / test
# 나머지 810에 대해서 모델만들고 train data로 이용한다
# Out:
# (418,)

# %%
test['Survived']=prediction
test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Age_mean', 'Gender',
#        'Embarked_S', 'Embarked_C', 'Embarked_Q', 'FamilySize', 'Family',
#        'Family_S', 'Family_M', 'Family_L', 'Survived'],
#       dtype='object')

# %%
submission=test[['PassengerId','Survived']]
submission.to_csv("submit.csv", index=False)

# %%
# 윤동주 시들에 대한 제목데이터 추출 
# or wikipedia total data 끌어오기 
# 음성 - 텍스트 - 영뮨 // 해당텍스트에 대한 적합한 대답 찾기 RNN / Wordembed
# RNN 기반( 순서 따져 )
# 유사도 기반 ( 순서 안따져 )
# 파이썬 코딩중에 변수 

# 정규 표현법 
# \w+\s*\w*\s*\=*\s*\"*\d*\"*\;*
# [\w\d\"\s\=\;]+

 # 코사인 유사도 
# 네이버 파파고 API 따와서 라이브러리 활용

# %%
# urllib:url을 다루는 모듈의 집합 
# urllib.request: 웹 데이터 접근
# 쿠키 : 서버쪽의 클라이언트(접속자)에 대한 남겨진 정보가 남는다 // 클라이언트 측에 남긴다
# 세션 : 서버쪽에 저장되는 내정보 
# 접속시에는 쿠키 // 통신시에는 세션을 사용해서 로그인상태를 유지한다 
import urllib.request
url="https://www.google.co.kr/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png"
sname="./data/data/hojin.png"
urllib.request.urlretrieve(url, sname)
print("저장됐습니다")
# 데이터 읽어서 저장 작업
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-9ddab9314463> in <module>
#       7 url="https://www.google.co.kr/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png"
#       8 sname="./data/data/data/hojin.png"
# ----> 9 urllib.request.urlretrieve(url, sname)
#      10 print("저장됐습니다")
#      11 # 데이터 읽어서 저장 작업
#
# ~\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     255         # Handle temporary file setup.
#     256         if filename:
# --> 257             tfp = open(filename, 'wb')
#     258         else:
#     259             tfp = tempfile.NamedTemporaryFile(delete=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/data/data/hojin.png'

# %%
import urllib.request
url="https://www.google.co.kr/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png"
sname="test.png"
mem=urllib.request.urlopen(url).read()
mem
with open(sname, mode="wb" ) as f: # test.png
    f.write(mem)
    print("이미지가 또 저장됐습니다.")
