# %%
# day17_quiz01
import numpy as np
from math import sqrt
from jupyterthemes import jtplot
jtplot.style(theme='gruvboxd', context='paper', spines=True, 
             ticks=True, grid=True, gridlines='dotted', figsize=(6,4.5))

# %%
# 문제 1
# y에서 yhat까지의 비용을 계산하는 cost 함수를 만드세요.
# def costToYhat(y, yhat):
# y(실제값)=3, 7, 10, 20
# yhat(예측값)=4, 13, 12, 30

# %%
def costToYhat(y,yhat):
    n = len(y)
    y = np.array(y)
    yh = np.array(yhat)
    
    sum_cost=np.sum(pow((y-yh),2)) 
    cost=1/n*(sum_cost)
    cost=sqrt(cost)
    
    return cost
    
y=[3,7,10,20]
yhat=[4,13,12,30]
print('costFunc:', costToYhat(y,yhat))
# Out:
# costFunc: 5.937171043518958

# %%
import matplotlib.pylab as plt
y=[3,7,10,20]
yhat=[4,13,12,30]
plt.plot(costToYhat(y,yhat))

# %%
# 문제 2 
# sigmoid 함수를 구현해 보세요.
# 호출예시) sigmoid 예측값 h(x)
# 변화되는 함수 반환값 시각화 

# print(sigmoid(-100))
# print(sigmoid(-10))
# print(sigmoid(0))
# print(sigmoid(10))
# print(sigmoid(100))

# %%
def sigmoid(val):
    e_sig = pow(np.e, -val)
    result = 1 / (1 + e_sig)
    return result

for i in [-100, -10, 0, 10, 100]:
    print('sigmoid({}):{}'.format(val,sigmoid(i)))
# Out:
# sigmoid(-100):3.7200759760208555e-44
# sigmoid(-100):4.539786870243442e-05
# sigmoid(-100):0.5
# sigmoid(-100):0.9999546021312976
# sigmoid(-100):1.0

# %%
# 문제 3
# -10에서 10까지에 대해 sigmoid 함수의 반환값을
# 그래프로 표시해 보세요.

# %%
# for i in range(-10, 10):
#     print('sigmoid({}):{}'.format(val,sigmoid(i)))
x = np.arange(-10, 10, 0.1)
y = [sigmoid(i) for i in x]

import matplotlib.pyplot as plt

from jupyterthemes import jtplot
jtplot.style(theme='gruvboxd', context='paper', spines=True, 
             ticks=True, grid=True, gridlines='dotted', figsize=(6,4.5))

plt.figure(figsize=(8,4))
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('sigmoid(x)')
# Out:
# Text(0, 0.5, 'sigmoid(x)')
